# %%
#!/usr/bin/env
from zipfile import ZipFile
import os

zip_file_path = './content/women-fashion.zip'
extraction_directory = './contents/women_fashion'

if not os.path.exists(extraction_directory):
    os.makedirs(extraction_directory)

with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 12
#       9     os.makedirs(extraction_directory)
#      11 with ZipFile(zip_file_path, 'r') as zip_ref:
# ---> 12     zip_ref.extractall(extraction_directory)
#
# File c:\Python39\lib\zipfile.py:1633, in ZipFile.extractall(self, path, members, pwd)
#    1630     path = os.fspath(path)
#    1632 for zipinfo in members:
# -> 1633     self._extract_member(zipinfo, path, pwd)
#
# File c:\Python39\lib\zipfile.py:1687, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1683         os.mkdir(targetpath)
#    1684     return targetpath
#    1686 with self.open(member, pwd=pwd) as source, \
# -> 1687      open(targetpath, "wb") as target:
#    1688     shutil.copyfileobj(source, target)
#    1690 return targetpath
#
# FileNotFoundError: [Errno 2] No such file or directory: 'contents\\women_fashion\\women fashion\\anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg'

# %%
extracted_files = os.listdir(extraction_directory)
print(extracted_files[:10])
# Out:
# ['women fashion', '__MACOSX']

# %%
#!/usr/bin/env
# correcting the path to include the 'women fashion' directory and listing its contents
extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')

# list the files in the updated directory
extracted_files_updated = os.listdir(extraction_directory_updated)
extracted_files_updated[:10], len(extracted_files_updated)
# Out:
# (['.DS_Store',
#   'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg',
#   'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg',
#   'beige top adorned with black dots and a green skirt.jpg',
#   'black floral saree.jpg',
#   'black lace bustier top paired with high-waisted black trousers.jpg',
#   'black off-shoulder dress with belt.jpg',
#   'black top with spaghetti straps and a black skirt adorned with a fringe detail at the hem.jpg',
#   'black top, white trousers.jpg',
#   'black, sequined dress with thin shoulder straps.jpg'],
#  59)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# function to load and display an image
def display_image(file_path):
    image = Image.open(file_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# display the first image to understand its characteristics
first_image_path = os.path.join(extraction_directory_updated, extracted_files_updated[1])
display_image(first_image_path)

# %%
import glob

# directory path containing your images
image_directory = './contents/women_fashion/women fashion'

image_paths_list = [file for file in glob.glob(os.path.join(image_directory, '*.*')) if file.endswith(('.jpg', '.png', '.jpeg', 'webp'))]

# print the list of image file paths
print(image_paths_list)
# Out:
# ['./contents/women_fashion/women fashion\\anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg', './contents/women_fashion/women fashion\\ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg', './contents/women_fashion/women fashion\\beige top adorned with black dots and a green skirt.jpg', './contents/women_fashion/women fashion\\black floral saree.jpg', './contents/women_fashion/women fashion\\black lace bustier top paired with high-waisted black trousers.jpg', './contents/women_fashion/women fashion\\black off-shoulder dress with belt.jpg', './contents/women_fashion/women fashion\\black top with spaghetti straps and a black skirt adorned with a fringe detail at the hem.jpg', './contents/women_fashion/women fashion\\black top, white trousers.jpg', './contents/women_fashion/women fashion\\black, sequined dress with thin shoulder straps.jpg', './contents/women_fashion/women fashion\\blue dress with a floral pattern.jpg', './contents/women_fashion/women fashion\\bright red, sequined dress with thin shoulder straps.jpg', './contents/women_fashion/women fashion\\burnt orange long-sleeve top, a plaid skirt with brown tones, and a matching burnt orange beret.jpeg', './contents/women_fashion/women fashion\\classic black slip dress with a midi length.jpg', './contents/women_fashion/women fashion\\colorful saree.jpg', './contents/women_fashion/women fashion\\cream-colored, long, open-front coat with wide lapels.jpg', './contents/women_fashion/women fashion\\dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg', './contents/women_fashion/women fashion\\deep burgundy, silky dress with long sleeves and a wrap-style front.jpg', './contents/women_fashion/women fashion\\dress with a classic black and white houndstooth pattern.jpg', './contents/women_fashion/women fashion\\fitted black dress that reaches down to mid-calf.jpg', './contents/women_fashion/women fashion\\fitted, off-the-shoulder white dress with horizontal ribbed texture.jpg', './contents/women_fashion/women fashion\\flowing green off-shoulder dress.jpg', './contents/women_fashion/women fashion\\fluffy, possibly faux fur or eyelash knit sweater with a cropped cut top.jpg', './contents/women_fashion/women fashion\\form-fitting dress with a vibrant pattern of yellow, blue, and black.jpg', './contents/women_fashion/women fashion\\l-htdrss7133-honky-tonky-original-imagszfhfghhs2rp.jpeg', './contents/women_fashion/women fashion\\ladies-party-wear-cotton-short-dress-full.jpg', './contents/women_fashion/women fashion\\Latest-Party-Wear-One-Piece-Gown-For-Women.webp', './contents/women_fashion/women fashion\\light blue, sequined dress with a V-neckline, long sleeves.jpg', './contents/women_fashion/women fashion\\light brown sleeveless double-breasted blazer paired with matching straight-leg trousers.jpg', './contents/women_fashion/women fashion\\light green, short dress with lace detailing around the waist and the edges of the sleeves and hem.jpg', './contents/women_fashion/women fashion\\long, elegant blue dress with an off-the-shoulder design with sheer sleeves.jpg', './contents/women_fashion/women fashion\\long, elegant, teal dress with a high slit on one side.jpg', './contents/women_fashion/women fashion\\long, flowing, pink dress with a sparkly texture.jpg', './contents/women_fashion/women fashion\\long, intricately designed dress with full sleeves.jpg', './contents/women_fashion/women fashion\\metallic-looking jacket with intricate designs and fringes hanging from the sleeves.jpg', './contents/women_fashion/women fashion\\mustard yellow fitted dress with white off-the-shoulder sleeves.webp', './contents/women_fashion/women fashion\\one-shoulder, black, sequined dress with fringe detailing at the hem.jpg', './contents/women_fashion/women fashion\\pink, knee-length dress that sparkles.jpg', './contents/women_fashion/women fashion\\red dress adorned with an intricate white pattern.jpg', './contents/women_fas ...

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=base_model.input, outputs=base_model.output)

def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array_expanded)
def extract_features(model, preprocessed_img):
    features = model.predict(preprocessed_img)
    flattened_features = features.flatten()
    normalized_features = flattened_features / np.linalg.norm(flattened_features)
    return normalized_features

all_features = []
all_image_names = []

for img_path in image_paths_list:
    preprocessed_img = preprocess_image(img_path)
    features = extract_features(model, preprocessed_img)
    all_features.append(features)
    all_image_names.append(os.path.basename(img_path))
# Out:
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step

# %%
from scipy.spatial.distance import cosine

def recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=5):
    # pre-process the input image and extract features
    preprocessed_img = preprocess_image(input_image_path)
    input_features = extract_features(model, preprocessed_img)

    # calculate similarities and find the top N similar images
    similarities = [1 - cosine(input_features, other_feature) for other_feature in all_features]
    similar_indices = np.argsort(similarities)[-top_n:]

    # filter out the input image index from similar_indices
    similar_indices = [idx for idx in similar_indices if idx != all_image_names.index(input_image_path)]

        # display the input image
    plt.figure(figsize=(15, 10))
    plt.subplot(1, top_n + 1, 1)
    plt.imshow(Image.open(input_image_path))
    plt.title("Input Image")
    plt.axis('off')

    # display similar images
    for i, idx in enumerate(similar_indices[:top_n], start=1):
        image_path = os.path.join('./contents/women_fashion/women fashion', all_image_names[idx])
        plt.subplot(1, top_n + 1, i + 1)
        plt.imshow(Image.open(image_path))
        plt.title(f"Recommendation {i}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
input_image_path = './contents/women_fashion/women fashion/dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg'
recommend_fashion_items_cnn(input_image_path, all_features, image_paths_list, model, top_n=4)
# Out:
# 1/1 [==============================] - 0s 122ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 input_image_path = './contents/women_fashion/women fashion/dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg'
# ----> 2 recommend_fashion_items_cnn(input_image_path, all_features, image_paths_list, model, top_n=4)
#
# Cell In[18], line 13, in recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n)
#      10 similar_indices = np.argsort(similarities)[-top_n:]
#      12 # filter out the input image index from similar_indices
# ---> 13 similar_indices = [idx for idx in similar_indices if idx != all_image_names.index(input_image_path)]
#      15     # display the input image
#      16 plt.figure(figsize=(15, 10))
#
# Cell In[18], line 13, in <listcomp>(.0)
#      10 similar_indices = np.argsort(similarities)[-top_n:]
#      12 # filter out the input image index from similar_indices
# ---> 13 similar_indices = [idx for idx in similar_indices if idx != all_image_names.index(input_image_path)]
#      15     # display the input image
#      16 plt.figure(figsize=(15, 10))
#
# ValueError: './contents/women_fashion/women fashion/dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg' is not in list
